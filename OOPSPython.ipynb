# %% [markdown]
# <a href="https://colab.research.google.com/github/samlocal/Python/blob/main/OOPSPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L=[1,2,3,4]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-917852281f28> in <cell line: 2>()
#       1 L=[1,2,3,4]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
S='sameeer'
S.append('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-85d73b9b5b76> in <cell line: 2>()
#       1 S='sameeer'
# ----> 2 S.append('a')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
#Every thing in python is a object

# %%
L=[1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
#class
#class contain data or property
#class name created using pascal case

# %%
#object
#object is an instance of class

#objectname=classname()

List1=list()

string = str()

# %%
class Atm:
  #constructor
  def __init__(self):
    self.pin=''
    self.balance=0
    self.menu()

  def menu(self):
    user_input=int(input("""
    Hi , How can i help you
    1.Create pin
    2.Change Pin
    3.Check Balance
    4.Withdraw
    5.Exit"""
    ))

    if(user_input==1):
      #create pin
      self.create_pin()
    elif(user_input==2):
      #change pin
      self.change_pin()
    elif(user_input==3):
      #check balance
      self.check_balance()

    elif(user_input==4):
      #withdraw
      self.withdraw()
    else:
      #exit
      pass

  def create_pin(self):
    user_pin=input("Enter pin")
    self.pin=user_pin

    user_balance=int(input("Enter ur balance"))
    self.balance=user_balance

    print('pin created successfully and balance are also updatfed')
    self.menu()

  def change_pin(self):
    user_old_pin=input("Enter old pin")
    if(user_old_pin==self.pin):
      new_user_pin=input("Enter new pin:")
      self.pin=new_user_pin
      print('pin changes successfully')
      self.menu()
    else:
      print("U enterd wrong old pin")
      self.menu()

  def check_balance(self):
    user_pin=input("Enter pin")
    if(user_pin==self.pin):
      print('ur balance is ',self.balance)
      self.menu()
    else:
      print('u entered wrong pin')
      self.menu()

  def withdraw(self):
    user_pin=input("Enter pin")
    if(user_pin==self.pin):
      withdraw_amount=int(input("Enter amount"))
      if(self.balance>=withdraw_amount):
        self.balance=self.balance-withdraw_amount
        print('Take ur ',withdraw_amount , " amount and balance is ",self.balance)
      else:
        print("Insufficient fund")
    else:
      print('u entered wrong pin')
      self.menu()

  # def exit_atm(self):
  #   exit()

# %%
obj1=Atm()
# print(type(obj1))
# Out:
#     Hi , How can i help you
#     1.Create pin
#     2.Change Pin
#     3.Check Balance
#     4.Withdraw
#     5.Exit1
# Enter pin111
# Enter ur balance100
# pin created successfully and balance are also updatfed
#
#     Hi , How can i help you
#     1.Create pin
#     2.Change Pin
#     3.Check Balance
#     4.Withdraw
#     5.Exit4
# Enter pin111
# Enter amount50
# Take ur  50  amount and balance is  50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-04934841d66a> in <cell line: 1>()
# ----> 1 obj1=Atm()
#       2 # print(type(obj1))
#
# <ipython-input-50-df27ca57c626> in __init__(self)
#       4     self.pin=''
#       5     self.balance=0
# ----> 6     self.menu()
#       7
#       8   def menu(self):
#
# <ipython-input-50-df27ca57c626> in menu(self)
#      18     if(user_input==1):
#      19       #create pin
# ---> 20       self.create_pin()
# ...

# %%
#Methods vs Functions
L=[1,2,3,4]
len(L) #function -> len() function does not belongs to class
L.append(5) #method -> append() function belongs to class

# %%
#class diagram

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Magic Methods/Dunder Methods
#special methods __name__

# while learning learn what is the use of it , when to use of it

# %%
#constructor
class Temp:
  def __init__(self):
    print('Hello bhai..')

obj1=Temp()
# Out:
# Hello bhai..

# %%
#constructor is used to write configuration related code
# eg : connecting with database

# %%
#self
class Temp1:
  def __init__(self):
    print(id(self))

obj1=Temp1()
print(id(obj1))
# Out:
# 136875614476928
# 136875614476928

# %%
obj2=Temp1()
print(id(obj2))
# Out:
# 136875616760880
# 136875616760880

# %%
#craeting fraction data type
class Fraction:
  #parameterized oconsrtuctor
  def __init__(self,x,y):
    self.num=x
    self.den=y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    return '{}/{}'.format((self.num*other.den)+(other.num*self.den),self.den*other.den)

  def __sub__(self,other):
    return '{}/{}'.format((self.num*other.den)-(other.num*self.den),self.den*other.den)

  def __mul__(self,other):
    return '{}/{}'.format((self.num*other.num),self.den*other.den)

  def __truediv__(self,other):
    return '{}/{}'.format((self.num*other.den),self.den*other.num)

  def convert_to_decimal(self):
    return self.num/self.den



fr1=Fraction(2,3)
print(fr1)

fr2=Fraction(3,8)
print(fr2)

print(fr1+fr2)
print(fr1-fr2)
print(fr1*fr2)
print(fr1/fr2)

print(fr1.convert_to_decimal())
# Out:
# 2/3
# 3/8
# 25/24
# 7/24
# 6/24
# 16/9
# 0.6666666666666666

# %%
#write oop classes to handle the following scenerios:
#1. A user can create and view 2D coordinates
#2. A user can find out the distance between two coordinates
#3. A user can find the distance of a coordinate from origin
#4. A user can check if a point lies on a given line
#5. A user can find the distance between a given 2D point and given line

# %%
class Point:
  def __init__(self,x,y):
    self.x_cod=x
    self.y_cod=y

  def __str__(self):
    return '<{},{}>'.format(self.x_cod,self.y_cod)

  def euclidian_distance(self,other):
    return ((self.x_cod - other.x_cod)**2+(self.y_cod-other.y_cod)**2)**0.5

  def distance_from_origin(self):
    return self.euclidian_distance(Point(0,0))
    # return ((self.x_cod - 0)**2+(self.y_cod-0)**2)**0.5 also ok





point1=Point(2,3)
print(point1)

point2=Point(1,1)
print(point2)

distance1=point1.euclidian_distance(point2)
print(distance1)

distance2=point1.distance_from_origin()
print(distance2)
# Out:
# <2,3>
# <1,1>
# 2.23606797749979
# 3.605551275463989

# %%
class Line:
  def __init__(self,A,B,C):
    self.A=A
    self.B=B
    self.C=C

  def __str__(self):
    return '{}X+{}Y+{}=0'.format(self.A,self.B,self.C)

  def point_on_line(line,point): #here self=line and point=other
    x=point.x_cod
    y=point.y_cod
    a=line.A
    b=line.B
    c=line.C

    if(a*x)+(b*y)+c==0:
      return True
    else:
      return False

  def distance_between_line_and_point(line,point):
    if(line.point_on_line(point)):
      return 0
    else:
      x=point.x_cod
      y=point.y_cod
      a=line.A
      b=line.B
      c=line.C

      num=abs((a*x)+(b*y)+c)
      den=(a**2 + b**2)**0.5

      return num/den

  def intersect_two_lines(line1,lin2):
    pass




line1=Line(1,1,-2)
print(line1)

point3=Point(1,1)
line1.point_on_line(point3)

line2=Line(2,1,4)
shortest_distance=line2.distance_between_line_and_point(Point(3,4))
print(shortest_distance)
# Out:
# 1X+1Y+-2=0
# 6.260990336999411

# %%
#How objects access atributes

class Person:
  def __init__(self,name,country_name):
    self.name=name
    self.country_name=country_name

  def greet(self):
    if(self.country_name=='India'):
      return 'Namaste {}'.format(self.name)
    else:
      return 'Hello {}'.format(self.name)

p1=Person('sameer','India')
p1.greet()

p2=Person('Johny','USA')
p2.greet()

#Accessing attributes
print(p2.name)
print(p2.country_name)
# Out:
# Johny
# USA

# %%
# Attribute creation from outside of the class
p2.gender='Female'
print(p2.gender)
# Out:
# Female

# %%
#Reference variable:
# Reference variable holds the object
# We can create objects without refernece variables as well
# An object can have multiple cariables
# Assigning a new references variable to an existing object does not create a new object

# %%
class Person:
  def __init__(self):
    self.name='sameer'
    self.age=23

obj1=Person()
print(obj1.name)
print(obj1.age)
# Out:
# sameer
# 23

# %%
obj2=obj1

obj2.name='sameer basha'
print(obj1.name,obj2.name)
# Out:
# sameer basha sameer basha

# %%
print(id(obj1),id(obj2))
# Out:
# 136169961177040 136169961177040

# %%
# Pass by reference
class Person:
  def __init__(self,name,gender):
    self.name=name
    self.gender=gender

def greet(person):
  return 'Hi I am {} gender is {}'.format(person.name,person.gender)

p=Person('sameer','Male')
greet(p) # passing object as a argument - pass by reference
# Out:
# 'Hi I am sameer gender is Male'

# %%
def fun1():
  p1=Person('Ram Charan','Male')
  return p1

funreturning=fun1()
print(funreturning)
print(funreturning.name)
print(funreturning.gender)
# Out:
# ...
# Ram Charan
# Male

# %%
class Dog:
  def __init__(self,breed,cost):
    self.breed=breed
    self.cost=cost

def dog_info(dog):
  print(dog.breed,dog.cost)
  dog.breed='Kangal'
  dog.cost=400000
  print(dog.breed,dog.cost)


d1=Dog('Alabai',500000)
dog_info(d1)
# Out:
# Alabai 500000
# Kangal 400000

# %%
#Instance variable
class Goat:
  def __init__(self,breed,origin):
    self.breed=breed
    self.origin=origin

g1=Goat('Kota','Rajasthan')
g2=Goat('xing','Ladakh')

print(g1.breed,g1.origin) #Instance variable
print(g2.breed,g2.origin) #Instance variable
# Out:
# Kota Rajasthan
# xing Ladakh

# %%
# Encapsulation
# private menbers of a class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# python is nothing truely private

# %%
# study setter and getter

# %%
# collections of objects
class Cat:
  def __init__(self,breed,color):
    self.breed=breed
    self.color=color

c1=Cat('Persian','Black')
c2=Cat('RugDoll','Grey')
c3=Cat('Bengal cat','Silver')

cat_list=[c1,c2,c3] # collections of objects

for i in cat_list:
  print(i.breed.upper())
# Out:
# PERSIAN
# RUGDOLL
# BENGAL CAT

# %%
#dict
cat_dict={'cat1':c1,'cat2':c2,'cat3':c3}

for i in cat_dict:
  print(cat_dict[i].color)
# Out:
# Black
# Grey
# Silver

# %%
#static variables
#utility methods
# staticmethod

# %%
# Class Relationship

# Aggregation
# Inheritance

# %%
# Aggregation (has-a-relationshop)
# one class owns the other class
# Customer(class) has a Aggress(class)
# Restuarant(class) has a Menu(class)

# %%
# Example
class Customer:
  def __init__(self,name,age,gender,address):
    self.name=name
    self.age=age
    self.address=address # we can say that address means not a single value or string  like name and age or gender, it is complex data structure that means it has street name, house number, road number, city,district,state so we make a new class for address

  def customer_address(self):
    print(self.address.get_city(),self.address.pincode,self.address.state)

  def edit_profile(self,new_name,new_city,new_pin,new_state):
    self.name=new_name
    self.address.edit_address(new_city,new_pin,new_state)




class Address:
  def __init__(self,city,pincode,state):
    self.__city=city
    self.pincode=pincode
    self.state=state

  def get_city(self):
    return self.__city

  def edit_address(self,new_city,new_pin,new_state):
    self.__city=new_city
    self.pincode=new_pin
    self.state=new_state


addr1=Address('Nandyal',518501,'Andhra Pradesh')
cust1=Customer('sameer',23,'Male',addr1)

cust1.customer_address()

cust1.edit_profile('sam','Vijayawada',12345,'Ap')
cust1.customer_address()
# Out:
# Nandyal 518501 Andhra Pradesh
# Vijayawada 12345 Ap

# %%
#Aggregation class diagram

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Inheritance

class User:
  def __init__(self):
    self.name='sameer'

  def login(self):
    print('login')

class Student(User): #child class
  def enroll(self):
    print('Enrolled into course')

u1=User()
s1=Student()

print(s1.name)
# Out:
# sameer

# %%
#wgat gets inherited
# Constructor
# Non Private Attributes
# Non Private Methods

# %%
# Constructor Example

class Phone:
  def __init__(self,price,brand,camera):
    print("Inside Phone Constructor")
    self.price=price
    self.brand=brand
    self.camera=camera
  def buy(self):
    print("Buying a Phone")

class SmartPhone(Phone):
  pass

s1=SmartPhone(2000,'iqoo','100px')
# Out:
# Inside Phone Constructor

# %%
# constructor example 2

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print ("Inside SmartPhone constructor")

s=SmartPhone("Android", 2)
# Out:
# Inside SmartPhone constructor

# %%
#child cannot access private meber of the class

class Phone:
  def __init__(self):
    self.__rate=900

class Iqoo(Phone):
  def amount(self):
    return self.rate

iqoo1=Iqoo()
iqoo1.rate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-243b078b8449> in <cell line: 12>()
#      10
#      11 iqoo1=Iqoo()
# ---> 12 iqoo1.rate
#
# AttributeError: 'Iqoo' object has no attribute 'rate'

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")

son=Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num):
        self.__val=val

    def get_val(self):
        return self.__val

son=Child(100,10)
print("Parent: Num:",son.get_num())
print("Child: Val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-5a17300f6fc7> in <cell line: 18>()
#      16
#      17 son=Child(100,10)
# ---> 18 print("Parent: Num:",son.get_num())
#      19 print("Child: Val:",son.get_val())
#
# <ipython-input-39-5a17300f6fc7> in get_num(self)
#       5
#       6     def get_num(self):
# ----> 7         return self.__num
#       8
#       9 class Child(Parent):
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1):
        print("class A :", self.var1)
class B(A):

    def display2(self,var1):
        print("class B :", self.var1)

obj=B()
obj.display1(200)
# Out:
# class A : 100

# %%
#Method Overriding
